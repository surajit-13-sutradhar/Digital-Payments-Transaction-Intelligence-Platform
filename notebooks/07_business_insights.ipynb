# %%
import pandas as pd

df = pd.read_csv("../data/processed/cleaned_transactions.csv")

print("Total 2024 TPV:", df["amount_inr"].sum())
print("Overall success rate:", (df["transaction_status"] == "SUCCESS").mean() * 100)
print("Fraud rate:", df["fraud_flag"].mean() * 100)
# Out:
# Total 2024 TPV: 327939009
# Overall success rate: 95.0496
# Fraud rate: 0.192
